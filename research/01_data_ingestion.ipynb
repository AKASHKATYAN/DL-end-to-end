# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Acer Nitro V 15\\Desktop\\kidney disease classificaton\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Acer Nitro V 15\\Desktop\\kidney disease classificaton'

# %%
from dataclasses import dataclass 
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir:Path
    source_URL:str
    local_data_file:Path
    unzip_dir:Path

# %%
from cnnClassifier.constants import *

# %%
from cnnClassifier.utils.common import create_directories

# %%
from cnnClassifier.utils.common import read_yaml

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH):
        
        self.config=read_yaml(config_filepath)
        self.params=read_yaml(params_filepath)
        
        create_directories([self.config.artifacts_root])
        
    def get_data_ingestion_config(self)->DataIngestionConfig:
        config=self.config.data_ingestion
        
        create_directories([config.root_dir])
        
        data_ingestion_config=DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir
        )    
        
        return data_ingestion_config

# %%
import os
import urllib.request as request
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self,config:DataIngestionConfig):
        self.config=config
    
    def download_file(self)->str:
      try:
        dataset_url=self.config.source_URL
        zip_download_dir=self.config.local_data_file
        os.makedirs("artifacts/data_ingestion",exist_ok=True)
        logger.info(f"Downloading data from {dataset_url}into file{zip_download_dir}")
        
        gdown.download(dataset_url,zip_download_dir)
        
        logger.info(f"Downlaoded data from {dataset_url} into file{zip_download_dir}")       
      except Exception as e:     
         raise e
    def extract_zip_file(self):    
        unzip_path=self.config.unzip_dir
        os.makedirs(unzip_path,exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file,'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:      
    config=ConfigurationManager()
    data_ingestion_config=config.get_data_ingestion_config()
    data_ingestion=DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [{'name': 'cnnClassifierLogger', 'msg': 'yaml file:config\\config.yaml loaded successfully', 'args': (), 'levelname': 'INFO', 'levelno': 20, 'pathname': 'c:\\users\\acer nitro v 15\\desktop\\kidney disease classificaton\\src\\cnnClassifier\\utils\\common.py', 'filename': 'common.py', 'module': 'common', 'exc_info': None, 'exc_text': None, 'stack_info': None, 'lineno': 30, 'funcName': 'read_yaml', 'created': 1778828732.9019732, 'msecs': 901.0, 'relativeCreated': 1225840.4173851013, 'thread': 341492, 'threadName': 'MainThread', 'processName': 'MainProcess', 'process': 341488, 'message': 'yaml file:config\\config.yaml loaded successfully'}(asctime)s:INFO:common:yaml file:config\config.yaml loaded successfully]
# [{'name': 'cnnClassifierLogger', 'msg': 'yaml file:params.yaml loaded successfully', 'args': (), 'levelname': 'INFO', 'levelno': 20, 'pathname': 'c:\\users\\acer nitro v 15\\desktop\\kidney disease classificaton\\src\\cnnClassifier\\utils\\common.py', 'filename': 'common.py', 'module': 'common', 'exc_info': None, 'exc_text': None, 'stack_info': None, 'lineno': 30, 'funcName': 'read_yaml', 'created': 1778828732.903972, 'msecs': 903.0, 'relativeCreated': 1225842.41604805, 'thread': 341492, 'threadName': 'MainThread', 'processName': 'MainProcess', 'process': 341488, 'message': 'yaml file:params.yaml loaded successfully'}(asctime)s:INFO:common:yaml file:params.yaml loaded successfully]
# [{'name': 'cnnClassifierLogger', 'msg': 'created directory at:artifacts', 'args': (), 'levelname': 'INFO', 'levelno': 20, 'pathname': 'c:\\users\\acer nitro v 15\\desktop\\kidney disease classificaton\\src\\cnnClassifier\\utils\\common.py', 'filename': 'common.py', 'module': 'common', 'exc_info': None, 'exc_text': None, 'stack_info': None, 'lineno': 43, 'funcName': 'create_directories', 'created': 1778828732.9049718, 'msecs': 904.0, 'relativeCreated': 1225843.4159755707, 'thread': 341492, 'threadName': 'MainThread', 'processName': 'MainProcess', 'process': 341488, 'message': 'created directory at:artifacts'}(asctime)s:INFO:common:created directory at:artifacts]
# [{'name': 'cnnClassifierLogger', 'msg': 'created directory at:artifacts/data_ingestion', 'args': (), 'levelname': 'INFO', 'levelno': 20, 'pathname': 'c:\\users\\acer nitro v 15\\desktop\\kidney disease classificaton\\src\\cnnClassifier\\utils\\common.py', 'filename': 'common.py', 'module': 'common', 'exc_info': None, 'exc_text': None, 'stack_info': None, 'lineno': 43, 'funcName': 'create_directories', 'created': 1778828732.9059715, 'msecs': 905.0, 'relativeCreated': 1225844.4156646729, 'thread': 341492, 'threadName': 'MainThread', 'processName': 'MainProcess', 'process': 341488, 'message': 'created directory at:artifacts/data_ingestion'}(asctime)s:INFO:common:created directory at:artifacts/data_ingestion]
# [{'name': 'cnnClassifierLogger', 'msg': 'Downloading data from https://drive.google.com/file/d/1osoP2WHKdISRWJh0vC40Ru728MXBM0G-/view?usp=sharinginto fileartifacts/data_ingestion/data.zip', 'args': (), 'levelname': 'INFO', 'levelno': 20, 'pathname': 'C:\\Users\\Acer Nitro V 15\\AppData\\Local\\Temp\\ipykernel_341488\\274691980.py', 'filename': '274691980.py', 'module': '274691980', 'exc_info': None, 'exc_text': None, 'stack_info': None, 'lineno': 10, 'funcName': 'download_file', 'created': 1778828732.9069717, 'msecs': 906.0, 'relativeCreated': 1225845.4158306122, 'thread': 341492, 'threadName': 'MainThread', 'processName': 'MainProcess', 'process': 341488, 'message': 'Downloading data from https://drive.google.com/file/d/1osoP2WHKdISRWJh0vC40Ru728MXBM0G-/view?usp=sharinginto fileartifacts/data_ingestion/data.zip'}(asctime)s:INFO:274691980:Downloading data from https://drive.google.com/file/d/1osoP2WHKdISRWJh0vC40Ru728MXBM0G-/view?usp=sharinginto fileartifacts/data_ingestion/data.zip]
# Downloading...
# From (original): https://drive.google.com/uc?id=1osoP2WHKdISRWJh0vC40Ru728MXBM0G-
# From (redirected): https://drive.google.com/uc?id=1osoP2WHKdISRWJh0vC40Ru728MXBM0G-&confirm=t&uuid=24dd719a-eecb-4d07-a94d-5af9ccce7115
# To: c:\Users\Acer Nitro V 15\Desktop\kidney disease classificaton\artifacts\data_ingestion\data.zip
# 100%|██████████| 938M/938M [04:15<00:00, 3.67MB/s]
# [{'name': 'cnnClassifierLogger', 'msg': 'Downlaoded data from https://drive.google.com/file/d/1osoP2WHKdISRWJh0vC40Ru728MXBM0G-/view?usp=sharing into fileartifacts/data_ingestion/data.zip', 'args': (), 'levelname': 'INFO', 'levelno': 20, 'pathname': 'C:\\Users\\Acer Nitro V 15\\AppData\\Local\\Temp\\ipykernel_341488\\274691980.py', 'filename': '274691980.py', 'module': '274691980', 'exc_info': None, 'exc_text': None, 'stack_info': None, 'lineno': 14, 'funcName': 'download_file', 'created': 1778828992.8906603, 'msecs': 890.0, 'relativeCreated': 1485829.104423523, 'thread': 341492, 'threadName': 'MainThread', 'processName': 'MainProcess', 'process': 341488, 'message': 'Downlaoded data from https://drive.google.com/file/d/1osoP2WHKdISRWJh0vC40Ru728MXBM0G-/view?usp=sharing into fileartifacts/data_ingestion/data.zip'}(asctime)s:INFO:274691980:Downlaoded data from https://drive.google.com/file/d/1osoP2WHKdISRWJh0vC40Ru728MXBM0G-/view?usp=sharing into fileartifacts/data_ingestion/data.zip]
