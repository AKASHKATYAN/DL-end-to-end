# %%
#config box
d={"key":"val","key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2=ConfigBox({"key":"val","key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
#ensure annotations
def get_predict(x:int,y:int)->int:
    return x*y

# %%
get_predict(x=2,y=3)
# Out:
# 6

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1osoP2WHKdISRWJh0vC40Ru728MXBM0G-/view?usp=sharing"

# %%
# Out:
# '1osoP2WHKdISRWJh0vC40Ru728MXBM0G-'

# %%
gdown.download(url=url)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1osoP2WHKdISRWJh0vC40Ru728MXBM0G-
# From (redirected): https://drive.google.com/uc?id=1osoP2WHKdISRWJh0vC40Ru728MXBM0G-&confirm=t&uuid=1a953356-484b-4a4c-89f2-1e96c8f45176
# To: c:\Users\Acer Nitro V 15\Desktop\kidney disease classificaton\research\data.zip
# 100%|██████████| 938M/938M [04:12<00:00, 3.71MB/s]
# 'data.zip'
